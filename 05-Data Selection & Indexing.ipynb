# %% [markdown]
# # Data Selection
#
# The data selection methods for Pandas are very flexible.

# %% [markdown]
# ### Selecting Columns
#
# methods of selecting columns in pandas:
#
#  1. Using a dot notation.
#
#  **`Ex: data.column_name`** (Not recommended)
#
#
#  2. Using a square brackets and name of the column as a string.
#
#  **`Ex: data['column_name']`**
#
#
#  3. Using numeric `indexing` and the `iloc` selector.
#
#  **`Ex: data.iloc[ : , column_Index_nmber ]`**
#
#
#  4. square-brace selection with a list of column names,for selection of multiple columns
#
#  **`Ex : data[['column_name1','column_name2',..]]`**
#
#
#  5. using numeric indexing with the iloc selector and a list of column numbers
#
#   **`Ex : data.iloc[ : ,[col_Ind_nmber2,col_Ind_nmber1,col_Ind_nmber3,..]]`**

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import tennis data file

# %%
data = pd.read_csv('tennis.csv')

# %%
data
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
data.columns
# Out:
# Index(['outlook', 'temp', 'humidity', 'windy', 'play'], dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=14, step=1)

# %%
data['outlook'] # Select / View only "outlook" column
# Out:
# 0        sunny
# 1        sunny
# 2     overcast
# 3        rainy
# 4        rainy
# 5        rainy
# 6     overcast
# 7        sunny
# 8        sunny
# 9        rainy
# 10       sunny
# 11    overcast
# 12    overcast
# 13       rainy
# Name: outlook, dtype: object

# %%
data.outlook # select / view only "outlook" column using dot operator
# Out:
# 0        sunny
# 1        sunny
# 2     overcast
# 3        rainy
# 4        rainy
# 5        rainy
# 6     overcast
# 7        sunny
# 8        sunny
# 9        rainy
# 10       sunny
# 11    overcast
# 12    overcast
# 13       rainy
# Name: outlook, dtype: object

# %%
data.iloc[:,0]# Select / view all rows of "outlook" column based on index number
# Out:
# 0        sunny
# 1        sunny
# 2     overcast
# 3        rainy
# 4        rainy
# 5        rainy
# 6     overcast
# 7        sunny
# 8        sunny
# 9        rainy
# 10       sunny
# 11    overcast
# 12    overcast
# 13       rainy
# Name: outlook, dtype: object

# %%
data.iloc[:,0:3] # all rows of 3 columns
# Out:
#      outlook  temp humidity
# 0      sunny   hot     high
# 1      sunny   hot     high
# 2   overcast   hot     high
# 3      rainy  mild     high
# 4      rainy  cool   normal
# 5      rainy  cool   normal
# 6   overcast  cool   normal
# 7      sunny  mild     high
# 8      sunny  cool   normal
# 9      rainy  mild   normal
# 10     sunny  mild   normal
# 11  overcast  mild     high
# 12  overcast   hot   normal
# 13     rainy  mild     high

# %%
data[['outlook','temp','humidity']]
# Out:
#      outlook  temp humidity
# 0      sunny   hot     high
# 1      sunny   hot     high
# 2   overcast   hot     high
# 3      rainy  mild     high
# 4      rainy  cool   normal
# 5      rainy  cool   normal
# 6   overcast  cool   normal
# 7      sunny  mild     high
# 8      sunny  cool   normal
# 9      rainy  mild   normal
# 10     sunny  mild   normal
# 11  overcast  mild     high
# 12  overcast   hot   normal
# 13     rainy  mild     high

# %%
data.iloc[:,[2,3,4]]
# Out:
#    humidity  windy play
# 0      high  False   no
# 1      high   True   no
# 2      high  False  yes
# 3      high  False  yes
# 4    normal  False  yes
# 5    normal   True   no
# 6    normal   True  yes
# 7      high  False   no
# 8    normal  False  yes
# 9    normal  False  yes
# 10   normal   True  yes
# 11     high   True  yes
# 12   normal  False  yes
# 13     high   True   no

# %% [markdown]
# ### Selecting rows
#
# Rows in a DataFrame are selected, typically, using the `iloc/loc` selection methods, or using logical selectors (selecting based on the value of another column or variable).
#
# The basic methods to get your heads around are:
#
#  1. numeric row selection using the iloc selector.
#
#    **`Ex : data.iloc[0:10, :] # select the first 10 rows of all columns`**
#
#
#  2. label-based row selection using the loc selector (this is only applicably if you have set an “index” on your dataframe.
#
#    **`Ex : data.loc[10,: ]`**
#
#
#  3. logical-based row selection using evaluated statements.
#
#    **`Ex : data[data['outlook'] == 'sunny'] # select the rows where `outlook` value is `sunny``**.

# %%
data.iloc[ 0:10, : ]
# Out:
#     outlook  temp humidity  windy play
# 0     sunny   hot     high  False   no
# 1     sunny   hot     high   True   no
# 2  overcast   hot     high  False  yes
# 3     rainy  mild     high  False  yes
# 4     rainy  cool   normal  False  yes
# 5     rainy  cool   normal   True   no
# 6  overcast  cool   normal   True  yes
# 7     sunny  mild     high  False   no
# 8     sunny  cool   normal  False  yes
# 9     rainy  mild   normal  False  yes

# %%
data.iloc[0:10,1:4]
# Out:
#    temp humidity  windy
# 0   hot     high  False
# 1   hot     high   True
# 2   hot     high  False
# 3  mild     high  False
# 4  cool   normal  False
# 5  cool   normal   True
# 6  cool   normal   True
# 7  mild     high  False
# 8  cool   normal  False
# 9  mild   normal  False

# %%
data.iloc[0:10:2,2:5]
# Out:
#   humidity  windy play
# 0     high  False   no
# 2     high  False  yes
# 4   normal  False  yes
# 6   normal   True  yes
# 8   normal  False  yes

# %%
data.loc[2]
# Out:
# outlook     overcast
# temp             hot
# humidity        high
# windy          False
# play             yes
# Name: 2, dtype: object

# %%
data.loc[9] # Select / View only 9th row
# Out:
# outlook      rainy
# temp          mild
# humidity    normal
# windy        False
# play           yes
# Name: 9, dtype: object

# %%
data.loc[[2,3,9]] # select 2nd,3rd,9th row
# Out:
#     outlook  temp humidity  windy play
# 2  overcast   hot     high  False  yes
# 3     rainy  mild     high  False  yes
# 9     rainy  mild   normal  False  yes

# %%
data.loc[[2,3,9],['outlook','play']]
# Out:
#     outlook play
# 2  overcast  yes
# 3     rainy  yes
# 9     rainy  yes

# %% [markdown]
# ### data.iloc
#
# Purely integer-location based indexing for selection by position.
#
# ``.iloc[]`` is primarily integer position based (from ``0`` to
# ``length-1`` of the axis), but may also be used with a boolean
# array.

# %% [raw]
# syntax : data.iloc[ row_selection , column_selection ]
#
# - Integer list of rows : [0,2,4]  ,  Interger list of columns : [2,1,4]
#
#   -   slice of rows    : [4 : 7]  ,       Slice of columns    : [4 : 7]
#
#   -    single value    : 1        ,       single value        : 1

# %% [markdown]
# ### data.loc
#
# Access a group of rows and columns by label(s) or a boolean array.
#
# ``.loc[]`` is primarily label based, but may also be used with a
# boolean array.

# %% [raw]
# syntax :  data.loc[ row_selection , column_selection ]
#
# - Index / Lable value : 'Index name'                  , Named column : 'column name'
#
# - List of Lables : ['Label1','Label2',..]             , List of column names : ['col name1','col name2',...]
#
# - Logical / Boolean Index : data[data['temp']=='hot'] , slice of columns : 'outlook':'humidity'

# %%
data
# Out:
#      outlook  temp humidity  windy play
# 0      sunny   hot     high  False   no
# 1      sunny   hot     high   True   no
# 2   overcast   hot     high  False  yes
# 3      rainy  mild     high  False  yes
# 4      rainy  cool   normal  False  yes
# 5      rainy  cool   normal   True   no
# 6   overcast  cool   normal   True  yes
# 7      sunny  mild     high  False   no
# 8      sunny  cool   normal  False  yes
# 9      rainy  mild   normal  False  yes
# 10     sunny  mild   normal   True  yes
# 11  overcast  mild     high   True  yes
# 12  overcast   hot   normal  False  yes
# 13     rainy  mild     high   True   no

# %%
data.index = ['R1','R2','R3','R4','R5','R6','R7','R8','R9','R10','R11','R12','R13','R14']

# %%
data
# Out:
#       outlook  temp humidity  windy play
# R1      sunny   hot     high  False   no
# R2      sunny   hot     high   True   no
# R3   overcast   hot     high  False  yes
# R4      rainy  mild     high  False  yes
# R5      rainy  cool   normal  False  yes
# R6      rainy  cool   normal   True   no
# R7   overcast  cool   normal   True  yes
# R8      sunny  mild     high  False   no
# R9      sunny  cool   normal  False  yes
# R10     rainy  mild   normal  False  yes
# R11     sunny  mild   normal   True  yes
# R12  overcast  mild     high   True  yes
# R13  overcast   hot   normal  False  yes
# R14     rainy  mild     high   True   no

# %%
data.iloc[0:10]
# Out:
#       outlook  temp humidity  windy play
# R1      sunny   hot     high  False   no
# R2      sunny   hot     high   True   no
# R3   overcast   hot     high  False  yes
# R4      rainy  mild     high  False  yes
# R5      rainy  cool   normal  False  yes
# R6      rainy  cool   normal   True   no
# R7   overcast  cool   normal   True  yes
# R8      sunny  mild     high  False   no
# R9      sunny  cool   normal  False  yes
# R10     rainy  mild   normal  False  yes

# %%
data.loc['R1':'R10']
# Out:
#       outlook  temp humidity  windy play
# R1      sunny   hot     high  False   no
# R2      sunny   hot     high   True   no
# R3   overcast   hot     high  False  yes
# R4      rainy  mild     high  False  yes
# R5      rainy  cool   normal  False  yes
# R6      rainy  cool   normal   True   no
# R7   overcast  cool   normal   True  yes
# R8      sunny  mild     high  False   no
# R9      sunny  cool   normal  False  yes
# R10     rainy  mild   normal  False  yes

# %%
data.iloc[0:10,0:2]
# Out:
#       outlook  temp
# R1      sunny   hot
# R2      sunny   hot
# R3   overcast   hot
# R4      rainy  mild
# R5      rainy  cool
# R6      rainy  cool
# R7   overcast  cool
# R8      sunny  mild
# R9      sunny  cool
# R10     rainy  mild

# %%
data.iloc[0:5,0:3]
# Out:
#      outlook  temp humidity
# R1     sunny   hot     high
# R2     sunny   hot     high
# R3  overcast   hot     high
# R4     rainy  mild     high
# R5     rainy  cool   normal

# %%
data.iloc[[2,1,3],[2,1]]
# Out:
#    humidity  temp
# R3     high   hot
# R2     high   hot
# R4     high  mild

# %%
data.loc[['R3','R2','R4'],['humidity','temp']]
# Out:
#    humidity  temp
# R3     high   hot
# R2     high   hot
# R4     high  mild
